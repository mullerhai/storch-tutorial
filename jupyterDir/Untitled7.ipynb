// %%
import $ivy.`io.github.mullerhai::storch_core:0.6.1-1.15.2`
// Out:
// import $ivy.$

// %%
import org.bytedeco.pytorch
import org.bytedeco.javacpp.{FloatPointer, PointerScope}
import org.bytedeco.pytorch.{Example, InputArchive, OutputArchive, TensorExampleVectorIterator}
import org.bytedeco.pytorch.{ChunkDatasetOptions, Example, ExampleIterator, ExampleStack, ExampleVector}
import org.bytedeco.pytorch.global.torch as torchNative
import java.net.URL
import java.util.zip.GZIPInputStream
import java.nio.file.{Paths, Files, Path}
import scala.collection.{mutable, Set as KeySet}
import scala.util.{Try,Success,Failure,Using,Random}
import torch.Device.{CPU, CUDA}
import torch.internal.NativeConverters.{fromNative, toNative}
import torch.{---, ::, &&, Slice}
import torch.nn.functional as F
import torch.nn.modules.HasParams
import torch.optim.Adam
import torch.{ BFloat16 ,Float32 , Int64,Default, Tensor }
import torch.nn as nn
import torch.utils.data.{NormalTensorDataset,DataLoaderOptions,Dataset, DataLoader}
import torch.utils.data.dataset.custom.{MNIST, FashionMNIST}
import torch.utils.data.*
import torch.utils.data.dataloader.*
import torch.utils.data.datareader.ChunkDataReader
import torch.utils.data.dataset.*
import torch.utils.data.sampler.RandomSampler
import torch.numpy.TorchNumpy
import torch.numpy.enums.DType.Float32 as NPFloat32
import torch.numpy.matrix.NDArray
import TorchNumpy.loadNDArrayFromCSV
import torch.pandas.DataFrame
import torch.utils.trainer.LstmNet
// import torch.TestDataLoader
// Out:
// Resolving package/object name conflict in favor of package spire.compat. The object will be inaccessible.
// import org.bytedeco.pytorch
//
// import org.bytedeco.javacpp.{FloatPointer, PointerScope}
//
// import org.bytedeco.pytorch.{Example, InputArchive, OutputArchive, TensorExampleVectorIterator}
//
// import org.bytedeco.pytorch.{ChunkDatasetOptions, Example, ExampleIterator, ExampleStack, ExampleVector}
//
// import org.bytedeco.pytorch.global.torch as torchNative
//
// import java.net.URL
//
// import java.util.zip.GZIPInputStream
//
// import java.nio.file.{Paths, Files, Path}
//
// import scala.collection.{mutable, Set as KeySet}
//
// import scala.util.{Try,Success,Failure,Using,Random}
//
// import torch.Device.{CPU, CUDA}
//
// import torch.internal.NativeConverters.{fromNative, toNative}
//
// import torch.{---, ::, &&, Slice}
//
// import torch.nn.functional as F
//
// import torch.nn.modules.HasParams
//
// import torch.optim.Adam
//
// import torch.{ BFloat16 ,Float32 , Int64,Default, Tensor }
//
// import torch.nn as nn
//
// import torch.utils.data.{NormalTensorDataset,DataLoaderOptions,Dataset, DataLoader}
//
// import torch.utils.data.dataset.custom.{MNIST, FashionMNIST}
//
// import torch.utils.data.*
//
// import torch.utils.data.dataloader.*
//
// import torch.utils.data.datareader.ChunkDataReader
//
// import torch.utils.data.dataset.*
//
// import torch.utils.data.sampler.RandomSampler
//
// import torch.numpy.TorchNumpy
//
// import torch.numpy.enums.DType.Float32 as NPFloat32
//
// import torch.numpy.matrix.NDArray
//
// import TorchNumpy.loadNDArrayFromCSV
//
// import torch.pandas.DataFrame
//
// import torch.utils.trainer.LstmNet
// // import torch.TestDataLoader

// %%
def mainTrain(): Unit =
  val num_epochs = 100
  val batchSize = 1000
  val timeout = 10.0f
  val device = if torch.cuda.isAvailable then CUDA else CPU
  println(s"Using device: $device")
  System.setProperty("org.bytedeco.javacpp.nopointergc", "true")
  //  val model  = GruNet().to(device)
  //  val model = LstmNet().to(device)
  //  val model = RnnNet().to(device)
  val modelPahth = "D:\\data\\git\\storch-tutorial\\lstm-netss.pt"
  val dataPath = Paths.get("D:\\data\\FashionMNIST")
  val mnistTrain = FashionMNIST(dataPath, train = true, download = true)
  val mnistEval = FashionMNIST(dataPath, train = false)
//  val mnistTrain = MNIST(dataPath, train = true, download = true)
//  val mnistEval = MNIST(dataPath, train = false)
  val trainFeatures = mnistTrain.features.to(device)
  val trainTargets = mnistTrain.targets.to(device)
  val evalFeatures = mnistEval.features.to(device)
  val evalTargets = mnistEval.targets.to(device)
  val r = Random(seed = 0)
//  val exampleSeq = mnistTrain.map(x => new Example(x._1.native, x._2.native))
//  val exampleVector = new ExampleVector(exampleSeq *)
  val model = new LstmNet[Float32]().to(device)
  val criterion = torch.nn.loss.CrossEntropyLoss()
  val optimizer = Adam(model.parameters, lr = 1e-3, amsgrad = true)
  val optimizerCopy = Adam(model.parameters, lr = 1e-3, amsgrad = true)
  val sampler = new RandomSampler(mnistTrain.length)
  val batchSampler = new RandomSampler(mnistTrain.length)
  val trainLoader = new DataLoader(dataset = mnistTrain, batch_size = batchSize, shuffle = true, sampler = sampler, batch_sampler = batchSampler, timeout = timeout)
  val evalLoader = new DataLoader(dataset = mnistEval, batch_size = batchSize, shuffle = false, sampler = sampler, batch_sampler = batchSampler, timeout = timeout)
  for (epoch <- 1 to num_epochs) {
    model.train()
    var totalLoss = 0l
    // val exampleIter = trainLoader.iterator
    var batchIndex = 0
//    println(s"try to get all dataset iter step length = ${trainLoader}")
//    for ((inputs, targets) <- trainLoader.iteratorSeq) {
    for ((inputs, targets) <- trainLoader) {
      println(s"hhh epoch = $epoch,begin batchIndex = $batchIndex, inputs = ${inputs.shape}, targets = ${targets.shape}")
      Using.resource(new PointerScope()) { _ =>
        // 将数据移到目标设备
        val inputsDevice = inputs.to(device)
        val targetsDevice = targets.to(device)

        println(s"hhh epoch = $epoch,scope batchIndex = $batchIndex, inputs = ${inputs.shape}, targets = ${targets.shape}")
        // 前向传播
        val outputs = model(inputsDevice.reshape(-1, 28, 28).to(torch.float32))
                // val loss = criterion(outputs, targetsDevice)
                // 反向传播和优化
        println(s"model_output epoch = $epoch,scope batchIndex = $batchIndex, outputs = ${outputs.shape}")
        optimizer.zeroGrad()
                // loss.backward()
        optimizer.step()

        // totalLoss = totalLoss + loss.item.asInstanceOf[Long]

        println(s"hhh epoch = $epoch,end  batchIndex = $batchIndex ..")
        batchIndex = batchIndex + 1
        // 定期评估
        // if (batchIndex % eval_interval == 0) {
        //   val (evalLoss, accuracy) = evaluate()
        //   println(
        //     s"Epoch: $epoch, Iteration: ${batchIndex}, | Training loss: ${loss.item}%.4f " +
        //       s"Train Loss: ${totalLoss / eval_interval}, Eval Loss: $evalLoss, Accuracy: $accuracy"
        //   )
        //   totalLoss = 0.0f
        //   model.train()
        // }
      }

    }
    println(s"complete epoch = $epoch, batchIndex = $batchIndex ..")

    // 每个epoch结束后评估
    // val (evalLoss, accuracy) = evaluate()
    // println(s"Epoch $epoch completed. Eval Loss: $evalLoss, Accuracy: $accuracy")
  }
// Out:
// Resolving package/object name conflict in favor of package spire.compat. The object will be inaccessible.
// defined function mainTrain

// %%
mainTrain()
// Out:
// Using device: Device(CPU,-1)
// hhh epoch = 1,begin batchIndex = 0, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 0, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 0, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 0 ..
// hhh epoch = 1,begin batchIndex = 1, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 1, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 1, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 1 ..
// hhh epoch = 1,begin batchIndex = 2, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 2, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 2, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 2 ..
// hhh epoch = 1,begin batchIndex = 3, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 3, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 3, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 3 ..
// hhh epoch = 1,begin batchIndex = 4, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 4, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 4, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 4 ..
// hhh epoch = 1,begin batchIndex = 5, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 5, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 5, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 5 ..
// hhh epoch = 1,begin batchIndex = 6, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 6, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 6, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 6 ..
// hhh epoch = 1,begin batchIndex = 7, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 7, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 7, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 7 ..
// hhh epoch = 1,begin batchIndex = 8, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 8, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 8, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 8 ..
// hhh epoch = 1,begin batchIndex = 9, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 9, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 9, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 9 ..
// hhh epoch = 1,begin batchIndex = 10, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 10, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 10, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 10 ..
// hhh epoch = 1,begin batchIndex = 11, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 11, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 11, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 11 ..
// hhh epoch = 1,begin batchIndex = 12, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 12, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 12, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 12 ..
// hhh epoch = 1,begin batchIndex = 13, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 13, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 13, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 13 ..
// hhh epoch = 1,begin batchIndex = 14, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 14, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 14, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 14 ..
// hhh epoch = 1,begin batchIndex = 15, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 15, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 15, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 15 ..
// hhh epoch = 1,begin batchIndex = 16, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 16, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 16, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 16 ..
// hhh epoch = 1,begin batchIndex = 17, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 17, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 17, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 17 ..
// hhh epoch = 1,begin batchIndex = 18, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 18, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 18, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 18 ..
// hhh epoch = 1,begin batchIndex = 19, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 19, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 19, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 19 ..
// hhh epoch = 1,begin batchIndex = 20, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 20, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 20, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 20 ..
// hhh epoch = 1,begin batchIndex = 21, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 21, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 21, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 21 ..
// hhh epoch = 1,begin batchIndex = 22, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 22, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 22, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 22 ..
// hhh epoch = 1,begin batchIndex = 23, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 23, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 23, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 23 ..
// hhh epoch = 1,begin batchIndex = 24, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 24, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 24, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 24 ..
// hhh epoch = 1,begin batchIndex = 25, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 25, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 25, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 25 ..
// hhh epoch = 1,begin batchIndex = 26, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 26, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 26, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 26 ..
// hhh epoch = 1,begin batchIndex = 27, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 27, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 27, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 27 ..
// hhh epoch = 1,begin batchIndex = 28, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 28, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 28, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 28 ..
// hhh epoch = 1,begin batchIndex = 29, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 29, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 29, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 29 ..
// hhh epoch = 1,begin batchIndex = 30, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 30, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 30, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 30 ..
// hhh epoch = 1,begin batchIndex = 31, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 31, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 31, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 31 ..
// hhh epoch = 1,begin batchIndex = 32, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 32, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 32, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 32 ..
// hhh epoch = 1,begin batchIndex = 33, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 33, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 33, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 33 ..
// hhh epoch = 1,begin batchIndex = 34, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 34, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 34, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 34 ..
// hhh epoch = 1,begin batchIndex = 35, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 35, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 35, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 35 ..
// hhh epoch = 1,begin batchIndex = 36, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 36, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 36, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 36 ..
// hhh epoch = 1,begin batchIndex = 37, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 37, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 37, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 37 ..
// hhh epoch = 1,begin batchIndex = 38, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 38, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 38, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 38 ..
// hhh epoch = 1,begin batchIndex = 39, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 39, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 39, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 39 ..
// hhh epoch = 1,begin batchIndex = 40, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 40, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 40, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 40 ..
// hhh epoch = 1,begin batchIndex = 41, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 41, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 41, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 41 ..
// hhh epoch = 1,begin batchIndex = 42, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 42, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 42, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 42 ..
// hhh epoch = 1,begin batchIndex = 43, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 43, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 43, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 43 ..
// hhh epoch = 1,begin batchIndex = 44, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 44, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 44, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 44 ..
// hhh epoch = 1,begin batchIndex = 45, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 45, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 45, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 45 ..
// hhh epoch = 1,begin batchIndex = 46, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 46, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 46, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 46 ..
// hhh epoch = 1,begin batchIndex = 47, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 47, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 47, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 47 ..
// hhh epoch = 1,begin batchIndex = 48, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 48, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 48, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 48 ..
// hhh epoch = 1,begin batchIndex = 49, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 49, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 49, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 49 ..
// hhh epoch = 1,begin batchIndex = 50, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 50, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 50, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 50 ..
// hhh epoch = 1,begin batchIndex = 51, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 51, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 51, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 51 ..
// hhh epoch = 1,begin batchIndex = 52, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 52, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 52, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 52 ..
// hhh epoch = 1,begin batchIndex = 53, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 53, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 53, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 53 ..
// hhh epoch = 1,begin batchIndex = 54, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 54, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 54, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 54 ..
// hhh epoch = 1,begin batchIndex = 55, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 55, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 55, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 55 ..
// hhh epoch = 1,begin batchIndex = 56, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 56, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 56, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 56 ..
// hhh epoch = 1,begin batchIndex = 57, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 57, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 57, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 57 ..
// hhh epoch = 1,begin batchIndex = 58, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 58, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 58, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 58 ..
// hhh epoch = 1,begin batchIndex = 59, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 1,scope batchIndex = 59, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 1,scope batchIndex = 59, outputs = ArraySeq(1000, 10)
// hhh epoch = 1,end  batchIndex = 59 ..
// complete epoch = 1, batchIndex = 60 ..
// hhh epoch = 2,begin batchIndex = 0, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 0, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 0, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 0 ..
// hhh epoch = 2,begin batchIndex = 1, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 1, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 1, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 1 ..
// hhh epoch = 2,begin batchIndex = 2, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 2, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 2, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 2 ..
// hhh epoch = 2,begin batchIndex = 3, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 3, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 3, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 3 ..
// hhh epoch = 2,begin batchIndex = 4, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 4, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 4, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 4 ..
// hhh epoch = 2,begin batchIndex = 5, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 5, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 5, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 5 ..
// hhh epoch = 2,begin batchIndex = 6, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 6, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 6, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 6 ..
// hhh epoch = 2,begin batchIndex = 7, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 7, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 7, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 7 ..
// hhh epoch = 2,begin batchIndex = 8, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 8, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 8, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 8 ..
// hhh epoch = 2,begin batchIndex = 9, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 9, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 9, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 9 ..
// hhh epoch = 2,begin batchIndex = 10, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 10, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 10, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 10 ..
// hhh epoch = 2,begin batchIndex = 11, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 11, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 11, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 11 ..
// hhh epoch = 2,begin batchIndex = 12, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 12, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 12, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 12 ..
// hhh epoch = 2,begin batchIndex = 13, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 13, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 13, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 13 ..
// hhh epoch = 2,begin batchIndex = 14, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 14, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 14, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 14 ..
// hhh epoch = 2,begin batchIndex = 15, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 15, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 15, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 15 ..
// hhh epoch = 2,begin batchIndex = 16, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 16, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 16, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 16 ..
// hhh epoch = 2,begin batchIndex = 17, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 17, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 17, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 17 ..
// hhh epoch = 2,begin batchIndex = 18, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 18, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 18, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 18 ..
// hhh epoch = 2,begin batchIndex = 19, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 19, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 19, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 19 ..
// hhh epoch = 2,begin batchIndex = 20, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 20, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 20, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 20 ..
// hhh epoch = 2,begin batchIndex = 21, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 21, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 21, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 21 ..
// hhh epoch = 2,begin batchIndex = 22, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 22, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 22, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 22 ..
// hhh epoch = 2,begin batchIndex = 23, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 23, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 23, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 23 ..
// hhh epoch = 2,begin batchIndex = 24, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 24, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 24, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 24 ..
// hhh epoch = 2,begin batchIndex = 25, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 25, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 25, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 25 ..
// hhh epoch = 2,begin batchIndex = 26, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 26, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 26, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 26 ..
// hhh epoch = 2,begin batchIndex = 27, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 27, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 27, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 27 ..
// hhh epoch = 2,begin batchIndex = 28, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 28, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 28, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 28 ..
// hhh epoch = 2,begin batchIndex = 29, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 29, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 29, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 29 ..
// hhh epoch = 2,begin batchIndex = 30, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 30, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 30, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 30 ..
// hhh epoch = 2,begin batchIndex = 31, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 31, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 31, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 31 ..
// hhh epoch = 2,begin batchIndex = 32, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 32, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 32, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 32 ..
// hhh epoch = 2,begin batchIndex = 33, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 33, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 33, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 33 ..
// hhh epoch = 2,begin batchIndex = 34, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 34, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 34, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 34 ..
// hhh epoch = 2,begin batchIndex = 35, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 35, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 35, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 35 ..
// hhh epoch = 2,begin batchIndex = 36, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 36, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 36, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 36 ..
// hhh epoch = 2,begin batchIndex = 37, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 37, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 37, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 37 ..
// hhh epoch = 2,begin batchIndex = 38, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 38, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 38, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 38 ..
// hhh epoch = 2,begin batchIndex = 39, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 39, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 39, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 39 ..
// hhh epoch = 2,begin batchIndex = 40, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 40, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 40, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 40 ..
// hhh epoch = 2,begin batchIndex = 41, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 41, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 41, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 41 ..
// hhh epoch = 2,begin batchIndex = 42, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 42, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 42, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 42 ..
// hhh epoch = 2,begin batchIndex = 43, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 43, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 43, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 43 ..
// hhh epoch = 2,begin batchIndex = 44, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 44, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 44, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 44 ..
// hhh epoch = 2,begin batchIndex = 45, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 45, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 45, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 45 ..
// hhh epoch = 2,begin batchIndex = 46, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 46, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 46, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 46 ..
// hhh epoch = 2,begin batchIndex = 47, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 47, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 47, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 47 ..
// hhh epoch = 2,begin batchIndex = 48, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 48, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 48, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 48 ..
// hhh epoch = 2,begin batchIndex = 49, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 49, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 49, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 49 ..
// hhh epoch = 2,begin batchIndex = 50, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 50, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 50, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 50 ..
// hhh epoch = 2,begin batchIndex = 51, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 51, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 51, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 51 ..
// hhh epoch = 2,begin batchIndex = 52, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 52, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 52, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 52 ..
// hhh epoch = 2,begin batchIndex = 53, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 53, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 53, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 53 ..
// hhh epoch = 2,begin batchIndex = 54, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 54, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 54, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 54 ..
// hhh epoch = 2,begin batchIndex = 55, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 55, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 55, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 55 ..
// hhh epoch = 2,begin batchIndex = 56, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 56, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 56, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 56 ..
// hhh epoch = 2,begin batchIndex = 57, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 57, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 57, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 57 ..
// hhh epoch = 2,begin batchIndex = 58, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 58, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 58, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 58 ..
// hhh epoch = 2,begin batchIndex = 59, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 2,scope batchIndex = 59, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 2,scope batchIndex = 59, outputs = ArraySeq(1000, 10)
// hhh epoch = 2,end  batchIndex = 59 ..
// complete epoch = 2, batchIndex = 60 ..
// hhh epoch = 3,begin batchIndex = 0, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 0, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 0, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 0 ..
// hhh epoch = 3,begin batchIndex = 1, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 1, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 1, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 1 ..
// hhh epoch = 3,begin batchIndex = 2, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 2, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 2, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 2 ..
// hhh epoch = 3,begin batchIndex = 3, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 3, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 3, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 3 ..
// hhh epoch = 3,begin batchIndex = 4, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 4, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 4, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 4 ..
// hhh epoch = 3,begin batchIndex = 5, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 5, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 5, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 5 ..
// hhh epoch = 3,begin batchIndex = 6, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 6, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 6, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 6 ..
// hhh epoch = 3,begin batchIndex = 7, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 7, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 7, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 7 ..
// hhh epoch = 3,begin batchIndex = 8, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 8, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 8, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 8 ..
// hhh epoch = 3,begin batchIndex = 9, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 9, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 9, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 9 ..
// hhh epoch = 3,begin batchIndex = 10, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 10, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 10, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 10 ..
// hhh epoch = 3,begin batchIndex = 11, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 11, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 11, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 11 ..
// hhh epoch = 3,begin batchIndex = 12, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 12, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 12, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 12 ..
// hhh epoch = 3,begin batchIndex = 13, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 13, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 13, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 13 ..
// hhh epoch = 3,begin batchIndex = 14, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 14, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 14, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 14 ..
// hhh epoch = 3,begin batchIndex = 15, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 15, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 15, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 15 ..
// hhh epoch = 3,begin batchIndex = 16, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 16, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 16, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 16 ..
// hhh epoch = 3,begin batchIndex = 17, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 17, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 17, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 17 ..
// hhh epoch = 3,begin batchIndex = 18, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 18, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 18, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 18 ..
// hhh epoch = 3,begin batchIndex = 19, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 19, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 19, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 19 ..
// hhh epoch = 3,begin batchIndex = 20, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 20, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 20, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 20 ..
// hhh epoch = 3,begin batchIndex = 21, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 21, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 21, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 21 ..
// hhh epoch = 3,begin batchIndex = 22, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 22, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 22, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 22 ..
// hhh epoch = 3,begin batchIndex = 23, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 23, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 23, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 23 ..
// hhh epoch = 3,begin batchIndex = 24, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 24, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 24, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 24 ..
// hhh epoch = 3,begin batchIndex = 25, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 25, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 25, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 25 ..
// hhh epoch = 3,begin batchIndex = 26, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 26, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 26, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 26 ..
// hhh epoch = 3,begin batchIndex = 27, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 27, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 27, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 27 ..
// hhh epoch = 3,begin batchIndex = 28, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 28, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 28, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 28 ..
// hhh epoch = 3,begin batchIndex = 29, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 29, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 29, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 29 ..
// hhh epoch = 3,begin batchIndex = 30, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 30, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 30, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 30 ..
// hhh epoch = 3,begin batchIndex = 31, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 31, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 31, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 31 ..
// hhh epoch = 3,begin batchIndex = 32, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 32, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 32, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 32 ..
// hhh epoch = 3,begin batchIndex = 33, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 33, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 33, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 33 ..
// hhh epoch = 3,begin batchIndex = 34, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 3,scope batchIndex = 34, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 3,scope batchIndex = 34, outputs = ArraySeq(1000, 10)
// hhh epoch = 3,end  batchIndex = 34 ..
// hhh epoch = 3,begin batchIndex = 35, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// ...
// hhh epoch = 78,end  batchIndex = 48 ..
// hhh epoch = 78,begin batchIndex = 49, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 49, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 49, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 49 ..
// hhh epoch = 78,begin batchIndex = 50, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 50, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 50, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 50 ..
// hhh epoch = 78,begin batchIndex = 51, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 51, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 51, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 51 ..
// hhh epoch = 78,begin batchIndex = 52, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 52, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 52, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 52 ..
// hhh epoch = 78,begin batchIndex = 53, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 53, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 53, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 53 ..
// hhh epoch = 78,begin batchIndex = 54, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 54, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 54, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 54 ..
// hhh epoch = 78,begin batchIndex = 55, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 55, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 55, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 55 ..
// hhh epoch = 78,begin batchIndex = 56, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 56, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 56, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 56 ..
// hhh epoch = 78,begin batchIndex = 57, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 57, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 57, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 57 ..
// hhh epoch = 78,begin batchIndex = 58, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 58, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 58, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 58 ..
// hhh epoch = 78,begin batchIndex = 59, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 78,scope batchIndex = 59, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 78,scope batchIndex = 59, outputs = ArraySeq(1000, 10)
// hhh epoch = 78,end  batchIndex = 59 ..
// complete epoch = 78, batchIndex = 60 ..
// hhh epoch = 79,begin batchIndex = 0, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 0, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 0, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 0 ..
// hhh epoch = 79,begin batchIndex = 1, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 1, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 1, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 1 ..
// hhh epoch = 79,begin batchIndex = 2, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 2, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 2, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 2 ..
// hhh epoch = 79,begin batchIndex = 3, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 3, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 3, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 3 ..
// hhh epoch = 79,begin batchIndex = 4, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 4, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 4, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 4 ..
// hhh epoch = 79,begin batchIndex = 5, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 5, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 5, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 5 ..
// hhh epoch = 79,begin batchIndex = 6, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 6, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 6, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 6 ..
// hhh epoch = 79,begin batchIndex = 7, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 7, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 7, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 7 ..
// hhh epoch = 79,begin batchIndex = 8, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 8, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 8, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 8 ..
// hhh epoch = 79,begin batchIndex = 9, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 9, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 9, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 9 ..
// hhh epoch = 79,begin batchIndex = 10, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 10, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 10, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 10 ..
// hhh epoch = 79,begin batchIndex = 11, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 11, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 11, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 11 ..
// hhh epoch = 79,begin batchIndex = 12, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 12, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 12, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 12 ..
// hhh epoch = 79,begin batchIndex = 13, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 13, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 13, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 13 ..
// hhh epoch = 79,begin batchIndex = 14, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 14, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 14, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 14 ..
// hhh epoch = 79,begin batchIndex = 15, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 15, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 15, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 15 ..
// hhh epoch = 79,begin batchIndex = 16, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 16, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 16, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 16 ..
// hhh epoch = 79,begin batchIndex = 17, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 17, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 17, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 17 ..
// hhh epoch = 79,begin batchIndex = 18, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 18, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 18, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 18 ..
// hhh epoch = 79,begin batchIndex = 19, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 19, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 19, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 19 ..
// hhh epoch = 79,begin batchIndex = 20, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 20, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 20, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 20 ..
// hhh epoch = 79,begin batchIndex = 21, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 21, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 21, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 21 ..
// hhh epoch = 79,begin batchIndex = 22, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 22, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 22, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 22 ..
// hhh epoch = 79,begin batchIndex = 23, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 23, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 23, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 23 ..
// hhh epoch = 79,begin batchIndex = 24, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 24, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 24, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 24 ..
// hhh epoch = 79,begin batchIndex = 25, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 25, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 25, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 25 ..
// hhh epoch = 79,begin batchIndex = 26, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 26, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 26, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 26 ..
// hhh epoch = 79,begin batchIndex = 27, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 27, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 27, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 27 ..
// hhh epoch = 79,begin batchIndex = 28, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 28, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 28, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 28 ..
// hhh epoch = 79,begin batchIndex = 29, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 29, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 29, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 29 ..
// hhh epoch = 79,begin batchIndex = 30, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 30, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 30, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 30 ..
// hhh epoch = 79,begin batchIndex = 31, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 31, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 31, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 31 ..
// hhh epoch = 79,begin batchIndex = 32, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 32, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 32, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 32 ..
// hhh epoch = 79,begin batchIndex = 33, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 33, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 33, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 33 ..
// hhh epoch = 79,begin batchIndex = 34, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 34, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 34, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 34 ..
// hhh epoch = 79,begin batchIndex = 35, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 35, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 35, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 35 ..
// hhh epoch = 79,begin batchIndex = 36, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 36, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 36, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 36 ..
// hhh epoch = 79,begin batchIndex = 37, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 37, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 37, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 37 ..
// hhh epoch = 79,begin batchIndex = 38, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 38, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 38, outputs = ArraySeq(1000, 10)
// hhh epoch = 79,end  batchIndex = 38 ..
// hhh epoch = 79,begin batchIndex = 39, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// hhh epoch = 79,scope batchIndex = 39, inputs = ArraySeq(1000, 1, 28, 28), targets = ArraySeq(1000)
// model_output epoch = 79,scope batchIndex = 39, outputs = ArraySeq(1000, 10)
